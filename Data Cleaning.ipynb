# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('test_data.csv')
df
# Out:
#    ID     Name   Age       City  Score
# 0   1   Alicia  25.0         NY   85.0
# 1   2      Bob   NaN         LA   92.0
# 2   3  Charlie  22.0    Chicago   -1.0
# 3   4  Dominic  19.0    Houston   65.0
# 4   5      Eve  31.0    Phoenix   78.0
# 5   6    Frank  35.0     Boston    NaN
# 6   7    Grace   NaN     Austin   55.0
# 7   8    Heidi  18.0  San Diego   90.0

# %%
df.describe()
# Out:
#             ID       Age      Score
# count  8.00000   6.00000   7.000000
# mean   4.50000  25.00000  66.285714
# std    2.44949   6.78233  32.576650
# min    1.00000  18.00000  -1.000000
# 25%    2.75000  19.75000  60.000000
# 50%    4.50000  23.50000  78.000000
# 75%    6.25000  29.50000  87.500000
# max    8.00000  35.00000  92.000000

# %% [markdown]
# ### Filtering a DataFrame

# %%
age_filt = df[(df['Age'] > 18)]
age_filt
# Out:
#    ID     Name   Age     City  Score
# 0   1   Alicia  25.0       NY   85.0
# 2   3  Charlie  22.0  Chicago   -1.0
# 3   4  Dominic  19.0  Houston   65.0
# 4   5      Eve  31.0  Phoenix   78.0
# 5   6    Frank  35.0   Boston    NaN

# %%
score_filt = df[(df['Score'] > 50) & (df['Score'] < 100 )]
score_filt
# Out:
#    ID     Name   Age       City  Score
# 0   1   Alicia  25.0         NY   85.0
# 1   2      Bob   NaN         LA   92.0
# 3   4  Dominic  19.0    Houston   65.0
# 4   5      Eve  31.0    Phoenix   78.0
# 6   7    Grace   NaN     Austin   55.0
# 7   8    Heidi  18.0  San Diego   90.0

# %% [markdown]
# ### Modifying a DataFrame

# %%
df_cleaned = df
df_cleaned.drop([2, 5], axis=0, inplace=True)
# dropped rows contained NaN values and less than 0 values
df_cleaned
# Out:
#    ID     Name   Age       City  Score
# 0   1   Alicia  25.0         NY   85.0
# 1   2      Bob   NaN         LA   92.0
# 3   4  Dominic  19.0    Houston   65.0
# 4   5      Eve  31.0    Phoenix   78.0
# 6   7    Grace   NaN     Austin   55.0
# 7   8    Heidi  18.0  San Diego   90.0

# %%
df_cleaned.drop(['City'], axis=1, inplace=True)
df_cleaned
# Out:
#    ID     Name   Age  Score
# 0   1   Alicia  25.0   85.0
# 1   2      Bob   NaN   92.0
# 3   4  Dominic  19.0   65.0
# 4   5      Eve  31.0   78.0
# 6   7    Grace   NaN   55.0
# 7   8    Heidi  18.0   90.0

# %%
df_cleaned['Age'] = df_cleaned.Age.fillna(25.0) 
# mean Age of the df is 25.0 from line 3 where df.describe() was run
df_cleaned
# Out:
#    ID     Name   Age  Score
# 0   1   Alicia  25.0   85.0
# 1   2      Bob  25.0   92.0
# 3   4  Dominic  19.0   65.0
# 4   5      Eve  31.0   78.0
# 6   7    Grace  25.0   55.0
# 7   8    Heidi  18.0   90.0

# %%
df_cleaned.replace({'Score':0}, 66.285714, inplace=True)
# mean Score of the df is retreived from line 3 where df.describe() was run
df_cleaned
# Out:
#    ID     Name   Age  Score
# 0   1   Alicia  25.0   85.0
# 1   2      Bob  25.0   92.0
# 3   4  Dominic  19.0   65.0
# 4   5      Eve  31.0   78.0
# 6   7    Grace  25.0   55.0
# 7   8    Heidi  18.0   90.0

# %%
df_cleaned.dropna()
c
